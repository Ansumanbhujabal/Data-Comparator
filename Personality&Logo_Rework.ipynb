# %%
! pip install zip
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 456.4/456.4 kB 9.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.8/45.8 kB 2.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.7/42.7 kB 3.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 3.1 MB/s eta 0:00:00
# ...
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# prompt: unzip ! unzip ("/content/Personality_formatting.zip")

# !unzip "/content/Logo_Rework.zip"
# Out:
# Archive:  /content/Logo_Rework.zip
#   inflating: Agriculture_Career_image_urls_logo.xlsx
#   inflating: Manufacturing_Careers_image_urls_logo.xlsx
#   inflating: Human_Careers_image_urls_logo.xlsx
#   inflating: Government_Careers_image_urls_logo.xlsx
#   inflating: Education_Careers_image_urls_logo.xlsx
#   inflating: Architecture_Careers_image_urls_logo.xlsx
#   inflating: Transport_Careers_image_urls_logo.xlsx
#   inflating: Hospitality_Careers_image_urls_logo.xlsx
#   inflating: Arts_Careers_image_urls_logo.xlsx
#   inflating: Law_Careers_image_urls_logo.xlsx
#   inflating: Health_Science_Careers_image_urls_logo.xlsx
#   inflating: finance_Careers_image_urls_logo.xlsx
#   inflating: Marketing_Careers_image_urls_logo.xlsx
#   inflating: Business_Management_image_urls_logo.xlsx
#   inflating: IT_image_urls_logo.xlsx
#   inflating: STEM_LOGO_URLS_V2.xlsx
#   inflating: STEM_image_urls_logo.xlsx
#   inflating: STEM_LOGO_URLS_V1.xlsx
#   inflating: STEM_image_urls_logo_1.xlsx

# %%
# prompt: merge all the xlsx files into a single xlsx row wise

import pandas as pd
import os

def merge_xlsx_files(directory):
    """
    Merges all XLSX files in a directory into a single XLSX file row-wise.

    Args:
        directory: The path to the directory containing the XLSX files.
    """

    all_dataframes = []
    for filename in os.listdir(directory):
        if filename.endswith(".xlsx"):
            filepath = os.path.join(directory, filename)
            try:
                df = pd.read_excel(filepath)
                all_dataframes.append(df)
            except Exception as e:
                print(f"Error reading {filename}: {e}")

    if not all_dataframes:
        print("No XLSX files found in the directory.")
        return

    merged_df = pd.concat(all_dataframes, ignore_index=True)
    merged_df.to_excel("merged_output_logo.xlsx", index=False)
    print("Merged files successfully into merged_output.xlsx")


# Example usage: Replace with your actual directory
merge_xlsx_files("/content/") # Assuming the files are in the unzipped directory
# Out:
# Merged files successfully into merged_output.xlsx

# %%
df=pd.read_excel("/content/merged_output_logo.xlsx")

# %%
len(df)
# Out:
# 6152

# %%
df.head(100)
# Out:
#                                          Search Query  \
# 0                                         SIFS India
# 1                         Hindustan Unilever Limited
# 2                                Okaya Power Group
# 3                           Hindustan Zinc Limited
# 4                                    Veolia India
# ..                                                ...
# 95                               Apollo Diagnostics
# 96   Indira Gandhi Centre for Atomic Research (IGC...
# 97                                        Netflix
# 98   National Bureau of Plant Genetic Resources (N...
# 99                         State Electricity Boards
#
#                                             Image URL
# 0   ......
# 1   ......
# 2   ......
# 3   ......
# 4   ......
# ..                                                ...
# 95  ......
# 96  ......
# 97  ......
# 98  ......
# 99  ......
#
# [100 rows x 2 columns]

# %% [markdown]
# # **Personality URL Clustering**

# %%
df1=pd.read_excel("/content/merged_output_Personality.xlsx")

# %%
df.head()
# Out:
#            Search Query                                          Image URL
# 0           Ratan Tata   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 1     Dhirubhai Ambani   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 2         Fouaad Mirza   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 3  G. V. Ramanjaneyulu   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 4      Dinesh K Sarraf   https://encrypted-tbn0.gstatic.com/images?q=tb...

# %%
df2=pd.read_excel("/content/Personalitylist.xlsx")

# %%
df2.head(1)
# Out:
#                   Career Name  \
# 0  Civil Engineer, Irrigation
#
#                                 Famous Personalities  \
# 0  Dr. Mihir Shah  \nRajendra Singh  \nAnupam Mis...
#
#                                        Top Companies
# 0  Jain Irrigation Systems \nNetafim Irrigation I...

# %%
df2["Career Name"][0]
# Out:
# 'Civil Engineer, Irrigation'

# %%
df2["Famous Personalities"][0]
# Out:
# 'Dr. Mihir Shah  \nRajendra Singh  \nAnupam Mishra  \nAyyappa Masagi '

# %%
import pandas as pd
import re

# Load df1 and df2 from Excel files (replace 'file1.xlsx' and 'file2.xlsx' with your filenames)
# df1 = pd.read_excel("file1.xlsx")  # Example
# df2 = pd.read_excel("file2.xlsx")  # Example

# Function to normalize names (remove whitespace, punctuation, and case)
def normalize(name):
    return re.sub(r'[^\w]', '', str(name).lower())

# Create a mapping of normalized names to URLs from df1
name_to_url = {
    normalize(row['Search Query']): row['Image URL']
    for _, row in df1.iterrows()
}

# Function to find matching URLs for names in df2
def find_urls(names):
    urls = []
    for name in str(names).split("\n"):
        normalized_name = normalize(name)
        if normalized_name in name_to_url:
            urls.append(name_to_url[normalized_name])
    return "\n".join(urls)  # Join URLs with newlines

# Add a new column to df2 with matching URLs
df2['Matched URLs'] = df2['Famous Personalities'].apply(find_urls)

# Save the updated df2 to a new Excel file
df2.to_excel("updated_file.xlsx", index=False)

print("Updated file saved as 'updated_file.xlsx'")
# Out:
# Updated file saved as 'updated_file.xlsx'

# %%
df3=pd.read_excel("/content/updated_file.xlsx")

# %%
df3.head()
# Out:
#                        Career Name  \
# 0       Civil Engineer, Irrigation
# 1  General Manager, Livestock Farm
# 2               Sugar Technologist
# 3                Boiling In-Charge
# 4            Veterinarian, General
#
#                                 Famous Personalities  \
# 0  Dr. Mihir Shah  \nRajendra Singh  \nAnupam Mis...
# 1  Verghese Kurien  \nDr. A. S. Faroda  \nDr. Man...
# 2                                                  -
# 3                                                  -
# 4  Dr. Vallabhbhai Kathiria  \nDr. Pawan Kumar An...
#
#                                        Top Companies  \
# 0  Jain Irrigation Systems \nNetafim Irrigation I...
# 1  Amul \nVenkateshwara Hatcheries Pvt Ltd \nSugu...
# 2  Balrampur Chini Mills Ltd \nDhampur Sugar Mill...
# 3  Shree Renuka Sugars Ltd \nBalrampur Chini Mill...
# 4  Indian Veterinary Research Institute \nVeterin...
#
#                                         Matched URLs
# ...

# %%
# Count the number of names in 'Famous Personalities'
def count_names(cell):
    return len(str(cell).split("\n"))

# Count the number of URLs in 'Matched URLs'
def count_urls(cell):
    return len(str(cell).split("\n"))

# Identify rows where counts do not match
df3['Name Count'] = df3['Famous Personalities'].apply(count_names)
df3['URL Count'] = df3['Matched URLs'].apply(count_urls)

# Filter rows where counts differ
mismatched_rows = df3[df3['Name Count'] != df3['URL Count']]

# Print mismatched rows
print(mismatched_rows[['Famous Personalities', 'Matched URLs', 'Name Count', 'URL Count']])
# Out:
#                                    Famous Personalities  \
# 13    Apollo Tyres Ltd \nMRF Ltd \nJK Tyre & Industr...
# 66    Indian Council of Forestry Research and Educat...
# 78    Indian Council of Forestry Research and Educat...
# 99    Drilling Assistant \nDriller \nDrilling Superv...
# 130   Junior In-Charge \nFruits and Vegetables Selec...
# ...                                                 ...
# 3386  Captain Radhika Menon  \nCaptain C. A. J. Vand...
# 3471  Amazon India \nFlipkart \nReliance Industries ...
# 3509  Indian Railways \nDelhi Metro Rail Corporation...
# 3528  Shipping Corporation of India \nGreat Eastern ...
# 3661  Larsen & Toubro  \nTata Projects Limited \nGam...
#
#                                            Matched URLs  Name Count  URL Count
# 13                                                  NaN           5          1
# 66                                                  NaN           5          1
# ...

# %% [markdown]
# # **Logo Url Formatting**

# %%
df1=pd.read_excel("/content/merged_output_logo (1).xlsx")

# %%
df1.head()
# Out:
#                    Search Query  \
# 0                   SIFS India
# 1   Hindustan Unilever Limited
# 2          Okaya Power Group
# 3     Hindustan Zinc Limited
# 4              Veolia India
#
#                                            Image URL
# 0  ......
# 1  ......
# 2  ......
# 3  ......
# 4  ......

# %%
df2=pd.read_excel("/content/Personalitylist.xlsx")

# %%
df2.head(1)
# Out:
#                   Career Name  \
# 0  Civil Engineer, Irrigation
#
#                                 Famous Personalities  \
# 0  Dr. Mihir Shah  \nRajendra Singh  \nAnupam Mis...
#
#                                        Top Companies
# 0  Jain Irrigation Systems \nNetafim Irrigation I...

# %%
df2['Top Companies']
# Out:
# 0       Jain Irrigation Systems \nNetafim Irrigation I...
# 1       Amul \nVenkateshwara Hatcheries Pvt Ltd \nSugu...
# 2       Balrampur Chini Mills Ltd \nDhampur Sugar Mill...
# 3       Shree Renuka Sugars Ltd \nBalrampur Chini Mill...
# 4       Indian Veterinary Research Institute \nVeterin...
#                               ...
# 3662    Coal India Limited \nNational Mineral Developm...
# 3663    Coal India Limited \nNational Mineral Developm...
# 3664    Larsen &Toubro \nTata Projects Limited \nHindu...
# 3665    Tata Steel \nReliance Industries \nAditya Birl...
# 3666    Indian Railways \nDelhi Metro Rail Corporation...
# Name: Top Companies, Length: 3667, dtype: object

# %%
import pandas as pd
import re

# Load df1 and df2 from Excel files (replace 'file1.xlsx' and 'file2.xlsx' with your filenames)
# df1 = pd.read_excel("file1.xlsx")  # Example
# df2 = pd.read_excel("file2.xlsx")  # Example

# Function to normalize names (remove whitespace, punctuation, and case)
def normalize(name):
    return re.sub(r'[^\w]', '', str(name).lower())

# Create a mapping of normalized names to URLs from df1
name_to_url = {
    normalize(row['Search Query']): row['Image URL']
    for _, row in df1.iterrows()
}

# Function to find matching URLs for names in df2
def find_urls(names):
    urls = []
    for name in str(names).split("\n"):
        normalized_name = normalize(name)
        if normalized_name in name_to_url:
            urls.append(name_to_url[normalized_name])
    return "\n".join(urls)  # Join URLs with newlines

# Add a new column to df2 with matching URLs
df2['Matched URLs'] = df2['Top Companies'].apply(find_urls)

# Save the updated df2 to a new Excel file
df2.to_excel("updated_logo_file.xlsx", index=False)

print("Updated file saved as 'updated_file.xlsx'")
# Out:
# Updated file saved as 'updated_file.xlsx'

# %%
df6=pd.read_excel("/content/updated_logo_file.xlsx")

# %%
df6.head()
# Out:
#                        Career Name  \
# 0       Civil Engineer, Irrigation
# 1  General Manager, Livestock Farm
# 2               Sugar Technologist
# 3                Boiling In-Charge
# 4            Veterinarian, General
#
#                                 Famous Personalities  \
# 0  Dr. Mihir Shah  \nRajendra Singh  \nAnupam Mis...
# 1  Verghese Kurien  \nDr. A. S. Faroda  \nDr. Man...
# 2                                                  -
# 3                                                  -
# 4  Dr. Vallabhbhai Kathiria  \nDr. Pawan Kumar An...
#
#                                        Top Companies  \
# 0  Jain Irrigation Systems \nNetafim Irrigation I...
# 1  Amul \nVenkateshwara Hatcheries Pvt Ltd \nSugu...
# 2  Balrampur Chini Mills Ltd \nDhampur Sugar Mill...
# 3  Shree Renuka Sugars Ltd \nBalrampur Chini Mill...
# 4  Indian Veterinary Research Institute \nVeterin...
#
#                                         Matched URLs
# 0  ......
# 1  ......
# 2  ......
# 3  ......
# ...

# %% [markdown]
# # **Jan9**

# %%
df=pd.read_excel("/content/companyName.xlsx")

# %%
df.head()
# Out:
#                       CompanyName
# 0              Allcargo Logistics
# 1               Blue Dart Express
# 2                        Gati Ltd
# 3  Transport Corporation of India
# 4                   VRL Logistics

# %%
len(df)
# Out:
# 9280

# %%
df2=pd.read_excel("/content/merged_output_logo (1).xlsx")

# %%
df2.head()
# Out:
#                    Search Query  \
# 0                   SIFS India
# 1   Hindustan Unilever Limited
# 2          Okaya Power Group
# 3     Hindustan Zinc Limited
# 4              Veolia India
#
#                                            Image URL
# 0  ......
# 1  ......
# 2  ......
# 3  ......
# 4  ......

# %%
len(df2)
# Out:
# 6152

# %%
# prompt: make a new excel where df[CompanyName] matcches with df2[Search Query] ignoring space , comma , case . The df[CompanyName] which did not match any add them in a faile dcase.json
import re
import json

def normalize_string(s):
    return re.sub(r'[^\w]', '', str(s).lower())

# Create a mapping of normalized company names to image URLs from df2
name_to_url = {
    normalize_string(row['Search Query']): row['Image URL']
    for _, row in df2.iterrows()
}

matched_results = []
failed_cases = []

for index, row in df.iterrows():
    company_name = normalize_string(row['CompanyName'])
    if company_name ==name_to_url(row['Search Query']):
        print(row['Search Query'])
        matched_results.append({
            'CompanyName': row['CompanyName'],
            'Image URL': name_to_url[company_name]
        })
    else:
        failed_cases.append(row['CompanyName'])

# Create a new DataFrame for matched results
matched_df = pd.DataFrame(matched_results)

# Save matched results to a new Excel file
matched_df.to_excel('matched_companies_rework.xlsx', index=False)

# Save failed cases to a JSON file
with open('failed_cases.json', 'w') as f:
    json.dump(failed_cases, f, indent=4)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Search Query'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-19ed9c82f8c9> in <cell line: 17>()
#      17 for index, row in df.iterrows():
# ...

# %%
import re
import json
import pandas as pd

def normalize_string(s):
    return re.sub(r'[^\w]', '', str(s).lower())

# Create a list to hold matched results and failed cases
matched_results = []
failed_cases = []

# Iterate through df rows
for _, row in df.iterrows():
    company_name = normalize_string(row['CompanyName'])
    matched = False

    # Iterate through df2 rows for strict comparison
    for _, row2 in df2.iterrows():
        search_query = normalize_string(row2['Search Query'])
        if company_name == search_query:  # Strict comparison
            matched_results.append({
                'CompanyName': row['CompanyName'],
                'Image URL': row2['Image URL']
            })
            matched = True
            break

    # If no match was found, add to failed cases
    if not matched:
        failed_cases.append(row['CompanyName'])

# Create a new DataFrame for matched results
matched_df = pd.DataFrame(matched_results)

# Save matched results to a new Excel file
matched_df.to_excel('matched_companies_rework.xlsx', index=False)

# Save failed cases to a JSON file
with open('failed_cases.json', 'w') as f:
    json.dump(failed_cases, f, indent=4)

# %%
df3=pd.read_excel("/content/matched_companies_rework_2.xlsx")

# %%
df3.head()
# Out:
#                       CompanyName  \
# 0              Allcargo Logistics
# 1               Blue Dart Express
# 2                        Gati Ltd
# 3  Transport Corporation of India
# 4                   VRL Logistics
#
#                                            Image URL
# 0  ......
# 1  ......
# 2  ......
# 3  ......
# 4  ......

# %%
len(df3)
# Out:
# 4171

# %% [markdown]
# # **Personality Rework Jan 9**

# %%
df=pd.read_excel("/content/Personalitylist (1).xlsx")

# %%
df.head()
# Out:
#                        Career Name  \
# 0       Civil Engineer, Irrigation
# 1  General Manager, Livestock Farm
# 2               Sugar Technologist
# 3                Boiling In-Charge
# 4            Veterinarian, General
#
#                                 Famous Personalities  \
# 0  Dr. Mihir Shah  \nRajendra Singh  \nAnupam Mis...
# 1  Verghese Kurien  \nDr. A. S. Faroda  \nDr. Man...
# 2                                                  -
# 3                                                  -
# 4  Dr. Vallabhbhai Kathiria  \nDr. Pawan Kumar An...
#
#                                        Top Companies
# 0  Jain Irrigation Systems \nNetafim Irrigation I...
# 1  Amul \nVenkateshwara Hatcheries Pvt Ltd \nSugu...
# 2  Balrampur Chini Mills Ltd \nDhampur Sugar Mill...
# 3  Shree Renuka Sugars Ltd \nBalrampur Chini Mill...
# 4  Indian Veterinary Research Institute \nVeterin...

# %% [markdown]
# # **Jan12 Rework**

# %%
# !git clone https://github.com/Ansumanbhujabal/Data-Comparator.git
# Out:
# Cloning into 'Data-Comparator'...
# remote: Enumerating objects: 46, done.
# remote: Total 46 (delta 0), reused 0 (delta 0), pack-reused 46 (from 1)
# Receiving objects: 100% (46/46), 90.25 MiB | 26.57 MiB/s, done.
# Resolving deltas: 100% (10/10), done.
# Updating files: 100% (35/35), done.

# %%
# !mv *.csv /content/Data-Comparator/
# Out:
# mv: cannot stat '*.csv': No such file or directory
# mv: '/content/Data-Comparator/' and './Data-Comparator' are the same file

# %%
# !rm -rf  /content/Data-Comparator/.lightning_studio/.ipynb_checkpoints

# %%
# !pip install pandas sentence-transformers scikit-learn

# %%
import pandas as pd
from sentence_transformers import SentenceTransformer, util
import numpy as np

# %%
df1=pd.read_csv("/content/Data-Comparator/companyName.csv")
df1.head()
# Out:
#                       CompanyName
# 0              Allcargo Logistics
# 1               Blue Dart Express
# 2                        Gati Ltd
# 3  Transport Corporation of India
# 4                   VRL Logistics

# %%
df2=pd.read_csv("/content/Data-Comparator/merged_output_Personality_jan9.csv")
df2.head()
# Out:
#            Search Query                                          Image URL
# 0           Ratan Tata   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 1     Dhirubhai Ambani   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 2         Fouaad Mirza   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 3  G. V. Ramanjaneyulu   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 4      Dinesh K Sarraf   https://encrypted-tbn0.gstatic.com/images?q=tb...

# %%
df3=pd.read_csv("/content/Data-Comparator/merged_output_logo_jan9.csv")
df3.head()
# Out:
#                    Search Query  \
# 0                   SIFS India
# 1   Hindustan Unilever Limited
# 2          Okaya Power Group
# 3     Hindustan Zinc Limited
# 4              Veolia India
#
#                                            Image URL
# 0  ......
# 1  ......
# 2  ......
# 3  ......
# 4  ......

# %%
# Load the data
small_list_df = pd.read_csv("/content/Data-Comparator/companyName.csv", header=None, names=["CompanyName"])
large_list_df = pd.read_csv("/content/Data-Comparator/merged_output_logo_jan9.csv", header=None, names=["Search Query"])
small_careers = small_list_df["CompanyName"].tolist()
large_careers = large_list_df["Search Query"].tolist()
model = SentenceTransformer('paraphrase-MiniLM-L6-v2')

# Encode the career names into vectors
small_embeddings = model.encode(small_careers, convert_to_tensor=True)
large_embeddings = model.encode(large_careers, convert_to_tensor=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.73k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/314 [00:00<?, ?B/s]
# ...

# %%
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer, util

# Load the data
df1 = pd.read_csv("/content/Data-Comparator/companyName.csv", header=None, names=["CompanyName"])
df3 = pd.read_csv("/content/Data-Comparator/merged_output_logo_jan9.csv", header=None, names=["Search Query", "Image URL"])

# Convert columns to lists
small_careers = df1["CompanyName"].tolist()
large_careers = df3["Search Query"].tolist()
image_urls = df3["Image URL"].tolist()

# Initialize lists for results
exact_matches = []
semantic_matches = []

# Find exact matches first
for small_career in small_careers:
    exact_match = [
        (large_career, image_urls[idx])
        for idx, large_career in enumerate(large_careers)
        if large_career.lower() == small_career.lower()
    ]
    if exact_match:
        exact_matches.append([small_career, exact_match[0][0], exact_match[0][1]])

# Save the exact matches to a DataFrame
exact_matches_df = pd.DataFrame(exact_matches, columns=["CompanyName", "Matched Search Query", "Image URL"])
exact_matches_df.to_csv("new_exact_matches_with_images.csv", index=False)

# Load the pre-trained Sentence-BERT model for semantic matching
model = SentenceTransformer('paraphrase-MiniLM-L6-v2')

# Encode the career names into vectors
small_embeddings = model.encode(small_careers, convert_to_tensor=True)
large_embeddings = model.encode(large_careers, convert_to_tensor=True)

# For semantic matches
for i, small_career in enumerate(small_careers):
    # Skip if it's already in the exact matches
    if any(small_career.lower() == exact_match[0].lower() for exact_match in exact_matches):
        continue

    # Compute cosine similarity between this career and all careers in the large list
    similarities = util.pytorch_cos_sim(small_embeddings[i], large_embeddings)

    # Get the index of the best match
    best_match_idx = similarities.argmax().item()

    # Get the corresponding Search Query and Image URL
    best_match_query = large_careers[best_match_idx]
    best_match_image_url = image_urls[best_match_idx]

    # Append the result to semantic matches
    semantic_matches.append([small_career, best_match_query, best_match_image_url])

# Convert the semantic matches to a DataFrame
semantic_matches_df = pd.DataFrame(semantic_matches, columns=["CompanyName", "Matched Search Query", "Image URL"])
semantic_matches_df.to_csv("/content/Data-Comparator/new_matches_with_images.csv", index=False)

print("Matching complete!")
print("Exact matches saved to 'exact_matches_with_images.csv'")
print("Semantic matches saved to 'semantic_matches_with_images.csv'")
# Out:
# Matching complete!
# Exact matches saved to 'exact_matches_with_images.csv'
# Semantic matches saved to 'semantic_matches_with_images.csv'

# %%
df5=pd.read_csv("/content/Data-Comparator/new_matches_with_images.csv")
df5.head()
# Out:
#                       CompanyName               Matched Search Query  \
# 0                     CompanyName               The Craft Company
# 1              Allcargo Logistics                Allcargo Logistics
# 2               Blue Dart Express                Blue Dart Express
# 3                        Gati Ltd                         Gati Ltd
# 4  Transport Corporation of India   Transport Corporation of India
#
#                                            Image URL
# 0  ......
# 1  ......
# 2  ......
# 3  ......
# 4  ......

# %%
import pandas as pd
import re

# Load the data
df5 = pd.read_csv("/content/Data-Comparator/new_matches_with_images.csv")

# Function to normalize strings by removing spaces, commas, dots, special signs, and making it lowercase
def normalize_string(s):
    return re.sub(r'[^a-z0-9]', '', s.lower())

# Filter rows where normalized CompanyName matches normalized Matched Search Query
filtered_df = df5[
    df5.apply(lambda row: normalize_string(row["CompanyName"]) == normalize_string(row["Matched Search Query"]), axis=1)
]

# Save the filtered DataFrame to a new CSV
filtered_df.to_csv("/content/Data-Comparator/new_v1_exact_normalized_matches.csv", index=False)

print("Filtered matches saved to 'exact_normalized_matches.csv'")
# Out:
# Filtered matches saved to 'exact_normalized_matches.csv'

# %%
df6=pd.read_csv("/content/Data-Comparator/new_v1_exact_normalized_matches.csv")
df6.head()
# Out:
#                       CompanyName               Matched Search Query  \
# 0              Allcargo Logistics                Allcargo Logistics
# 1               Blue Dart Express                Blue Dart Express
# 2                        Gati Ltd                         Gati Ltd
# 3  Transport Corporation of India   Transport Corporation of India
# 4                   VRL Logistics                     VRL Logistics
#
#                                            Image URL
# 0  ......
# 1  ......
# 2  ......
# 3  ......
# 4  ......

# %%
import pandas as pd
import re

# Load the data
df5 = pd.read_csv("/content/Data-Comparator/new_matches_with_images.csv")

# Function to normalize strings by removing spaces, commas, dots, special signs, and making it lowercase
def normalize_string(s):
    return re.sub(r'[^a-z0-9]', '', s.lower())

# Filter rows where normalized CompanyName matches normalized Matched Search Query
filtered_df = df5[
    df5.apply(lambda row: normalize_string(row["CompanyName"]) != normalize_string(row["Matched Search Query"]), axis=1)
]

# Save the filtered DataFrame to a new CSV
filtered_df.to_csv("/content/Data-Comparator/new_v1_unmatch_normalized_matches.csv", index=False)

print("Filtered matches saved to 'new_v1_unmatch_normalized_matches.csv'")
# Out:
# Filtered matches saved to 'new_v1_unmatch_normalized_matches.csv'

# %%
df7=pd.read_csv("/content/Data-Comparator/new_v1_unmatch_normalized_matches.csv")
df7.head()
# Out:
#              CompanyName        Matched Search Query  \
# 0            CompanyName        The Craft Company
# 1  120 Media Collectives                 HT Media
# 2              18 Pixels   HNG Float Glass Limited
# 3                1Point1           Ogilvy & Mather
# 4         20 Microns Ltd          Micron Technology
#
#                                            Image URL
# 0  ......
# 1  ......
# 2  ......
# 3  ......
# 4  ......

# %%
print(f"The total number of logo is {len(df3)}")
print(f"The length of total is {len(df1)}")
print(f"The length of total exact  match  is {len(df6)}")
print(f"The length of total  unmatch is {len(df7)}")
print(f"The total length combined is same as {len(df6)+len(df7)}")
# Out:
# The total number of logo is 6153
# The length of total is 9281
# The length of total exact  match  is 4143
# The length of total  unmatch is 5138
# The total length combined is same as 9281

# %%
df7.head(30)
# Out:
#               CompanyName                      Matched Search Query  \
# 0             CompanyName                      The Craft Company
# 1   120 Media Collectives                               HT Media
# 2               18 Pixels                 HNG Float Glass Limited
# 3                 1Point1                         Ogilvy & Mather
# 4          20 Microns Ltd                        Micron Technology
# 5         247 HEADHUNTING                     Head Diamond Grader
# 6           24X7 customer              Traffic Management Centers
# 7                  2Adpro                                    DTDC
# 8                     360             Illumination Entertainment
# 9           3D Architects                          DFI Architects
# 10        3D PLM Software                  Transerve Technologies
# 11                    3Di                 Pixar Animation Studios
# 12              3G Global                                  3M ESPE
# ...

# %%
## The total logo is 6153
## The total image I sent 3158
## The total image I sent in 2nd Phase 2618
## The total image sent is {3158+2618}
print(f"The total image sent is {3158+2618}") ##5776
print(f"The total Image missing {6153-5776}")
# Out:
# The total image sent is 5776
# The total Image missing 377

# %%
# prompt: find loc of '3M Healthcare ' in df7

import pandas as pd

# Assuming df7 is already loaded as shown in your provided code
# df7 = pd.read_csv("/content/Data-Comparator/new_v1_unmatch_normalized_matches.csv")

try:
  # Attempt to find the location of '3M Healthcare '
    location = df7.loc[df7['CompanyName'] == '3M ESPE']
    print(location)
except KeyError:
    print("'CompanyName' column not found in the DataFrame.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Empty DataFrame
# Columns: [CompanyName, Matched Search Query, Image URL]
# Index: []

# %%
df3.head()
# Out:
#                    Search Query  \
# 0                  Search Query
# 1                   SIFS India
# 2   Hindustan Unilever Limited
# 3          Okaya Power Group
# 4     Hindustan Zinc Limited
#
#                                            Image URL
# 0                                          Image URL
# 1  ......
# 2  ......
# 3  ......
# 4  ......

# %%
# prompt: find loc of '3M Healthcare ' in df7

import pandas as pd

# Assuming df7 is already loaded as shown in your provided code
# df7 = pd.read_csv("/content/Data-Comparator/new_v1_unmatch_normalized_matches.csv")

try:
  # Attempt to find the location of '3M Healthcare '
    location = df3.loc[df3['Search Query'] == '3M ESPE']
    print(location)
except KeyError:
    print("'CompanyName' column not found in the DataFrame.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Empty DataFrame
# Columns: [Search Query, Image URL]
# Index: []

# %% [markdown]
# # **Personality Rework**

# %%
pf1=pd.read_csv("/content/Data-Comparator/merged_output_Personality_jan9.csv")
print(f"The total no of personality images are {len(pf1)}")
pf1.head()
# Out:
# The total no of personality images are 2650
#            Search Query                                          Image URL
# 0           Ratan Tata   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 1     Dhirubhai Ambani   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 2         Fouaad Mirza   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 3  G. V. Ramanjaneyulu   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 4      Dinesh K Sarraf   https://encrypted-tbn0.gstatic.com/images?q=tb...

# %%
print(f"The total no of personality images  I have sent is {3383}")
# Out:
# The total no of personality images  I have sent is 3383

# %%
pf2=pd.read_csv("/content/Data-Comparator/famous_personality_redo.csv")
print(f"The total no of personality images missing are  {len(pf2)}")
pf2.head()
# Out:
# The total no of personality images missing are  1746
#    Unnamed: 0  Unnamed: 1  Unnamed: 2       firstname
# 0         NaN         NaN         NaN     A. K. Dutta
# 1         NaN         NaN         NaN  A. Lakshminath
# 2         NaN         NaN         NaN    A. Mahendran
# 3         NaN         NaN         NaN     A. S. Dulat
# 4         NaN         NaN         NaN      A. Sandesh

# %%
pf2['firstname'][0]
# Out:
# 'A. K. Dutta'

# %%
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer, util

# Load the data
pf1 = pd.read_csv("/content/Data-Comparator/famous_personality_redo.csv", header=None, names=["firstname"])
pf3 = pd.read_csv("/content/Data-Comparator/merged_output_Personality_jan9.csv", header=None, names=["Search Query", "Image URL"])

# Convert columns to lists
small_careers = pf1["firstname"].tolist()
# print((small_careers))
large_careers = pf3["Search Query"].tolist()
# print((large_careers))
image_urls = pf3["Image URL"].tolist()

# Initialize lists for results
exact_matches = []
semantic_matches = []

# # Find exact matches first
for small_career in small_careers:
  if not  isinstance(small_career,str):
    print(small_career)
    print(f"The small career is {small_career}")
    exact_match = [
        (large_career, image_urls[idx])
        for idx, large_career in enumerate(large_careers)
        if large_career.lower() == small_career.lower()
    ]
    if exact_match:
        exact_matches.append([small_career, exact_match[0][0], exact_match[0][1]])

# Save the exact matches to a DataFrame
exact_matches_df = pd.DataFrame(exact_matches, columns=["firstname", "Matched Search Query", "Image URL"])
exact_matches_df.to_csv("new_exact_matches_with_personality.csv", index=False)

# Load the pre-trained Sentence-BERT model for semantic matching
model = SentenceTransformer('paraphrase-MiniLM-L6-v2')

# Encode the career names into vectors
small_embeddings = model.encode(small_careers, convert_to_tensor=True)
large_embeddings = model.encode(large_careers, convert_to_tensor=True)

# For semantic matches
for i, small_career in enumerate(small_careers):
    # Skip if it's already in the exact matches
    if any(small_career.lower() == exact_match[0].lower() for exact_match in exact_matches):
        continue

    # Compute cosine similarity between this career and all careers in the large list
    similarities = util.pytorch_cos_sim(small_embeddings[i], large_embeddings)

    # Get the index of the best match
    best_match_idx = similarities.argmax().item()

    # Get the corresponding Search Query and Image URL
    best_match_query = large_careers[best_match_idx]
    best_match_image_url = image_urls[best_match_idx]

    # Append the result to semantic matches
    semantic_matches.append([small_career, best_match_query, best_match_image_url])

# Convert the semantic matches to a DataFrame
semantic_matches_df = pd.DataFrame(semantic_matches, columns=["firstname", "Matched Search Query", "Image URL"])
semantic_matches_df.to_csv("new_semantic_matches_with_personailty.csv", index=False)

print("Matching complete!")
print("Exact matches saved to 'exact_matches_with_images.csv'")
print("Semantic matches saved to 'semantic_matches_with_images.csv'")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.73k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/314 [00:00<?, ?B/s]
# ...

# %%
pf4=pd.read_csv("/content/new_semantic_matches_with_personailty.csv")
print(f"The Length of the semantic match is {len(pf4)}")
pf4.head(30)
# Out:
# The Length of the semantic match is 1747
#                           firstname  \
# 0                         firstname
# 1                       A. K. Dutta
# 2                    A. Lakshminath
# 3                      A. Mahendran
# 4                       A. S. Dulat
# 5                        A. Sandesh
# 6               A. Sivathanu Pillai
# 7                        A.D. Singh
# 8                A.P.J. Abdul Kalam
# 9                       A.R. Rahman
# 10                      Aabid Surti
# 11                      Aalim Hakim
# 12             Abanindranath Tagore
# 13                        ABC Farms
# 14                      Abdul Matin
# 15                   Abhay Kewadkar
# 16                   Abhijit Bansod
# 17                Adani Enterprises
# 18                      Adani Group
# 19  Additional Commissioner Customs
# 20      Additional Director General
# 21                   Adhuna Bhabani
# 22                       Adi Godrej
# 23                       Adil Malia
# ...

# %%
pf5=pd.read_csv("/content/new_exact_matches_with_images.csv")
print(f"The Length of the semantic match is {len(pf5)}")
pf5.head()
# Out:
# The Length of the semantic match is 0
# Empty DataFrame
# Columns: [CompanyName, Matched Search Query, Image URL]
# Index: []

# %%
import pandas as pd
import re

# Load the data
pf6 = pd.read_csv("/content/new_semantic_matches_with_personailty.csv")

# Function to normalize strings by removing spaces, commas, dots, special signs, and making it lowercase
def normalize_string(s):
    return re.sub(r'[^a-z0-9]', '', s.lower())

# Filter rows where normalized CompanyName matches normalized Matched Search Query
filtered_df = pf6[
    pf6.apply(lambda row: normalize_string(row["firstname"]) == normalize_string(row["Matched Search Query"]), axis=1)
]

# Save the filtered DataFrame to a new CSV
filtered_df.to_csv("new_v1_exact_Personality_normalized_matches.csv", index=False)

print("Filtered matches saved to 'exact_normalized_matches.csv'")
# Out:
# Filtered matches saved to 'exact_normalized_matches.csv'

# %%
pf7=pd.read_csv("/content/new_v1_exact_Personality_normalized_matches.csv")
print(f"The Length of the semantic match is {len(pf7)}")
pf7.head()
# Out:
# The Length of the semantic match is 1459
#         firstname Matched Search Query  \
# 0     A. K. Dutta         A. K. Dutta
# 1  A. Lakshminath      A. Lakshminath
# 2    A. Mahendran        A. Mahendran
# 3     A. S. Dulat         A. S. Dulat
# 4      A. Sandesh          A. Sandesh
#
#                                            Image URL
# 0  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 1  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 2  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 3  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 4  https://encrypted-tbn0.gstatic.com/images?q=tb...

# %%
import pandas as pd
import re

# Load the data
pf6 = pd.read_csv("/content/new_semantic_matches_with_personailty.csv")

# Function to normalize strings by removing spaces, commas, dots, special signs, and making it lowercase
def normalize_string(s):
    return re.sub(r'[^a-z0-9]', '', s.lower())

# Filter rows where normalized CompanyName matches normalized Matched Search Query
filtered_df = pf6[
    pf6.apply(lambda row: normalize_string(row["firstname"]) != normalize_string(row["Matched Search Query"]), axis=1)
]

# Save the filtered DataFrame to a new CSV
filtered_df.to_csv("new_v1_Unmatch_Personality_normalized_matches.csv", index=False)

print("Filtered matches saved to 'exact_normalized_matches.csv'")
# Out:
# Filtered matches saved to 'exact_normalized_matches.csv'

# %%
pf8=pd.read_csv("/content/new_v1_Unmatch_Personality_normalized_matches.csv")
print(f"The Length of the semantic match is {len(pf8)}")
pf8.head(50)
# Out:
# The Length of the semantic match is 288
#                                             firstname  \
# 0                                           firstname
# 1                                         Adani Group
# 2                     Additional Commissioner Customs
# 3                         Additional Director General
# 4                         Airports Authority of India
# 5                                        Amazon India
# 6                                  Amazon Prime Video
# 7                                              Anokhi
# 8                                    Apollo Hospitals
# 9                                        Apollo Tyres
# 10                                   Apollo Tyres Ltd
# 11                                            Apparel
# 12                                 Apprentice Artisan
# 13                                 Apprentice Plumber
# 14                                       Area Manager
# 15                                            Artisan
# ...
